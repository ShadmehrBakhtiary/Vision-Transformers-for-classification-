# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install medmnist
# Out:
# Collecting medmnist
#   Downloading medmnist-3.0.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from medmnist) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from medmnist) (2.0.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from medmnist) (1.3.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from medmnist) (0.23.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from medmnist) (4.66.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from medmnist) (9.4.0)
# Collecting fire (from medmnist)
#   Downloading fire-0.6.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 8.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from medmnist) (2.3.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from medmnist) (0.18.1+cu121)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fire->medmnist) (1.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire->medmnist) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->medmnist) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->medmnist) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->medmnist) (2024.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (3.3)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (2.34.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (2024.7.21)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (0.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->medmnist) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->medmnist) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (1.13.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (2024.6.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->medmnist)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->medmnist)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->medmnist)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->medmnist)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->medmnist)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->medmnist)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->medmnist)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->medmnist)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->medmnist)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->medmnist)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->medmnist)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->medmnist)
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->medmnist) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->medmnist) (1.3.0)
# Downloading medmnist-3.0.1-py3-none-any.whl (25 kB)
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 10.1 MB/s eta 0:00:00
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117029 sha256=d629e2c38066ff68b4cf1bae72c5082b634a85aa052d6821a888e510cd319604
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built fire
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, fire, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, medmnist
# Successfully installed fire-0.6.0 medmnist-3.0.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105

# %%
# !pip install tensorflow-addons
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (24.1)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 35.5 MB/s eta 0:00:00
# Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.3.0
#     Uninstalling typeguard-4.3.0:
#       Successfully uninstalled typeguard-4.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# inflect 7.3.1 requires typeguard>=4.0.1, but you have typeguard 2.13.3 which is incompatible.
# Successfully installed tensorflow-addons-0.23.0 typeguard-2.13.3

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
import medmnist
from medmnist import INFO, Evaluator
import math
import numpy as np
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
from tensorflow.keras import layers
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
print("Available datasets:")
print(list(medmnist.INFO.keys()))
# Out:
# Available datasets:
# ['pathmnist', 'chestmnist', 'dermamnist', 'octmnist', 'pneumoniamnist', 'retinamnist', 'breastmnist', 'bloodmnist', 'tissuemnist', 'organamnist', 'organcmnist', 'organsmnist', 'organmnist3d', 'nodulemnist3d', 'adrenalmnist3d', 'fracturemnist3d', 'vesselmnist3d', 'synapsemnist3d']

# %%
SEED = 42
keras.utils.set_random_seed(SEED)

# Constants
DATASET_NAME = 'bloodmnist'
NUM_CLASSES = 8
INPUT_SHAPE = (28, 28, 1)

# Download and prepare the dataset
info = medmnist.INFO[DATASET_NAME]
data_path = keras.utils.get_file(origin=info["url"], md5_hash=info["MD5"])

with np.load(data_path) as data:
    # Get images
    train_image = data["train_images"]
    valid_image = data["val_images"]
    test_image = data["test_images"]

    # Get labels
    train_labels = data["train_labels"].flatten()
    valid_labels = data["val_labels"].flatten()
    test_labels = data["test_labels"].flatten()

# Print shapes of loaded data
print(f"x_train shape: {train_image.shape} - y_train shape: {train_labels.shape}")
print(f"x_valid shape: {valid_image.shape} - y_valid shape: {valid_labels.shape}")
print(f"x_test shape: {test_image.shape} - y_test shape: {test_labels.shape}")
# Out:
# Downloading data from https://zenodo.org/records/10519652/files/bloodmnist.npz?download=1
# 35461855/35461855 [==============================] - 3s 0us/step
# x_train shape: (11959, 28, 28, 3) - y_train shape: (11959,)
# x_valid shape: (1712, 28, 28, 3) - y_valid shape: (1712,)
# x_test shape: (3421, 28, 28, 3) - y_test shape: (3421,)

# %% [markdown]
# # **Configure the hyperparameters**

# %%
# DATA
BUFFER_SIZE = 512
BATCH_SIZE = 256

# AUGMENTATION
IMAGE_SIZE = 72
PATCH_SIZE = 6
NUM_PATCHES = (IMAGE_SIZE // PATCH_SIZE) ** 2

# OPTIMIZER
LEARNING_RATE = 0.001
WEIGHT_DECAY = 0.0001

# TRAINING
EPOCHS = 50

# ARCHITECTURE
LAYER_NORM_EPS = 1e-6
TRANSFORMER_LAYERS = 8
PROJECTION_DIM = 64
NUM_HEADS = 4
TRANSFORMER_UNITS = [
    PROJECTION_DIM * 2,
    PROJECTION_DIM,
]
MLP_HEAD_UNITS = [2048, 1024]

# %% [markdown]
# # **Use data augmentation**

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(train_image)

# %% [markdown]
# # **Implement Shifted Patch Tokenization**

# %% [markdown]
# In a ViT pipeline, the input images are divided into patches that are then linearly projected into tokens. Shifted patch tokenization (STP) is introduced to combat the low receptive field of ViTs. The steps for Shifted Patch Tokenization are as follows:
#
#
#
# Start with an image.
#
# Shift the image in diagonal directions.
#
# Concat the diagonally shifted images with the original image.
#
# Extract patches of the concatenated images.
#
# Flatten the spatial dimension of all patches.
#
# Layer normalize the flattened patches and then project it.

# %% [markdown]
# ![bUnHxd0.png](data:image/png;base64,...)

# %%
class ShiftedPatchTokenization(layers.Layer):
    def __init__(
        self,
        image_size=IMAGE_SIZE,
        patch_size=PATCH_SIZE,
        num_patches=NUM_PATCHES,
        projection_dim=PROJECTION_DIM,
        vanilla=False,
        **kwargs,
    ):
        super().__init__(**kwargs)
        self.vanilla = vanilla  # Flag to swtich to vanilla patch extractor
        self.image_size = image_size
        self.patch_size = patch_size
        self.half_patch = patch_size // 2
        self.flatten_patches = layers.Reshape((num_patches, -1))
        self.projection = layers.Dense(units=projection_dim)
        self.layer_norm = layers.LayerNormalization(epsilon=LAYER_NORM_EPS)

    def crop_shift_pad(self, images, mode):
        # Build the diagonally shifted images
        if mode == "left-up":
            crop_height = self.half_patch
            crop_width = self.half_patch
            shift_height = 0
            shift_width = 0
        elif mode == "left-down":
            crop_height = 0
            crop_width = self.half_patch
            shift_height = self.half_patch
            shift_width = 0
        elif mode == "right-up":
            crop_height = self.half_patch
            crop_width = 0
            shift_height = 0
            shift_width = self.half_patch
        else:
            crop_height = 0
            crop_width = 0
            shift_height = self.half_patch
            shift_width = self.half_patch

        # Crop the shifted images and pad them
        crop = tf.image.crop_to_bounding_box(
            images,
            offset_height=crop_height,
            offset_width=crop_width,
            target_height=self.image_size - self.half_patch,
            target_width=self.image_size - self.half_patch,
        )
        shift_pad = tf.image.pad_to_bounding_box(
            crop,
            offset_height=shift_height,
            offset_width=shift_width,
            target_height=self.image_size,
            target_width=self.image_size,
        )
        return shift_pad

    def call(self, images):
        if not self.vanilla:
            # Concat the shifted images with the original image
            images = tf.concat(
                [
                    images,
                    self.crop_shift_pad(images, mode="left-up"),
                    self.crop_shift_pad(images, mode="left-down"),
                    self.crop_shift_pad(images, mode="right-up"),
                    self.crop_shift_pad(images, mode="right-down"),
                ],
                axis=-1,
            )
        # Patchify the images and flatten it
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        flat_patches = self.flatten_patches(patches)
        if not self.vanilla:
            # Layer normalize the flat patches and linearly project it
            tokens = self.layer_norm(flat_patches)
            tokens = self.projection(tokens)
        else:
            # Linearly project the flat patches
            tokens = self.projection(flat_patches)
        return (tokens, patches)

# %% [markdown]
# # **Implement the patch encoding layer**

# %% [markdown]
# This layer accepts projected patches and then adds positional information to them.

# %%
class PatchEncoder(layers.Layer):
    def __init__(
        self, num_patches=NUM_PATCHES, projection_dim=PROJECTION_DIM, **kwargs
    ):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )
        self.positions = tf.range(start=0, limit=self.num_patches, delta=1)

    def call(self, encoded_patches):
        encoded_positions = self.position_embedding(self.positions)
        encoded_patches = encoded_patches + encoded_positions
        return encoded_patches

# %% [markdown]
# # **Implement Locality Self Attention**
# The attention module takes a query, key, and value. First, we compute the similarity between the query and key via a dot product. Then, the result is scaled by the square root of the key dimension. The scaling prevents the softmax function from having an overly small gradient. Softmax is then applied to the scaled dot product to produce the attention weights. The value is then modulated via the attention weights.
#
# In self-attention, query, key and value come from the same input. The dot product would result in large self-token relations rather than inter-token relations. This also means that the softmax gives higher probabilities to self-token relations than the inter-token relations. To combat this, the authors propose masking the diagonal of the dot product. This way, we force the attention module to pay more attention to the inter-token relations.
#
# The scaling factor is a constant in the regular attention module. This acts like a temperature term that can modulate the softmax function. The authors suggest a learnable temperature term instead of a constant.

# %% [markdown]
# ![GTV99pk.png](data:image/png;base64,...)

# %% [markdown]
# The above two pointers make the Locality Self Attention. We have subclassed the layers.MultiHeadAttention and implemented the trainable temperature. The attention mask is built at a later stage.

# %%
class MultiHeadAttentionLSA(tf.keras.layers.MultiHeadAttention):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        # The trainable temperature term. The initial value is
        # the square root of the key dimension.
        self.tau = tf.Variable(math.sqrt(float(self._key_dim)), trainable=True)

    def _compute_attention(self, query, key, value, attention_mask=None, training=None):
        query = tf.multiply(query, 1.0 / self.tau)
        attention_scores = tf.einsum(self._dot_product_equation, key, query)
        attention_scores = self._masked_softmax(attention_scores, attention_mask)
        attention_scores_dropout = self._dropout_layer(
            attention_scores, training=training
        )
        attention_output = tf.einsum(
            self._combine_equation, attention_scores_dropout, value
        )
        return attention_output, attention_scores

# %% [markdown]
# ***Implement the MLP***

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x


# Build the diagonal attention mask
diag_attn_mask = 1 - tf.eye(NUM_PATCHES)
diag_attn_mask = tf.cast([diag_attn_mask], dtype=tf.int8)

# %% [markdown]
# # **Build the ViT**

# %%
def create_vit_classifier(vanilla=False):
    inputs = layers.Input(shape=INPUT_SHAPE)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    (tokens, _) = ShiftedPatchTokenization(vanilla=vanilla)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder()(tokens)

    # Create multiple layers of the Transformer block.
    for _ in range(TRANSFORMER_LAYERS):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        if not vanilla:
            attention_output = MultiHeadAttentionLSA(
                num_heads=NUM_HEADS, key_dim=PROJECTION_DIM, dropout=0.1
            )(x1, x1, attention_mask=diag_attn_mask)
        else:
            attention_output = layers.MultiHeadAttention(
                num_heads=NUM_HEADS, key_dim=PROJECTION_DIM, dropout=0.1
            )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=TRANSFORMER_UNITS, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=MLP_HEAD_UNITS, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(NUM_CLASSES)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %% [markdown]
# # **Compile, train, and evaluate the mode**

# %%
class WarmUpCosine(keras.optimizers.schedules.LearningRateSchedule):
    def __init__(
        self, learning_rate_base, total_steps, warmup_learning_rate, warmup_steps
    ):
        super().__init__()

        self.learning_rate_base = learning_rate_base
        self.total_steps = total_steps
        self.warmup_learning_rate = warmup_learning_rate
        self.warmup_steps = warmup_steps
        self.pi = tf.constant(np.pi)

    def __call__(self, step):
        if self.total_steps < self.warmup_steps:
            raise ValueError("Total_steps must be larger or equal to warmup_steps.")

        cos_annealed_lr = tf.cos(
            self.pi
            * (tf.cast(step, tf.float32) - self.warmup_steps)
            / float(self.total_steps - self.warmup_steps)
        )
        learning_rate = 0.5 * self.learning_rate_base * (1 + cos_annealed_lr)

        if self.warmup_steps > 0:
            if self.learning_rate_base < self.warmup_learning_rate:
                raise ValueError(
                    "Learning_rate_base must be larger or equal to "
                    "warmup_learning_rate."
                )
            slope = (
                self.learning_rate_base - self.warmup_learning_rate
            ) / self.warmup_steps
            warmup_rate = slope * tf.cast(step, tf.float32) + self.warmup_learning_rate
            learning_rate = tf.where(
                step < self.warmup_steps, warmup_rate, learning_rate
            )
        return tf.where(
            step > self.total_steps, 0.0, learning_rate, name="learning_rate"
        )


def run_experiment(model):
    total_steps = int((len(train_image) / BATCH_SIZE) * EPOCHS)
    warmup_epoch_percentage = 0.10
    warmup_steps = int(total_steps * warmup_epoch_percentage)
    scheduled_lrs = WarmUpCosine(
        learning_rate_base=LEARNING_RATE,
        total_steps=total_steps,
        warmup_learning_rate=0.0,
        warmup_steps=warmup_steps,
    )

    optimizer = tfa.optimizers.AdamW(
        learning_rate=LEARNING_RATE, weight_decay=WEIGHT_DECAY
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    history = model.fit(
        x=train_image,
        y=train_labels,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_split=0.1,
    )
    _, accuracy, top_5_accuracy = model.evaluate(test_image, test_labels, batch_size=BATCH_SIZE)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

def plot_accuracy(history):
    # Plot training and validation accuracy
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(loc='upper left')
    plt.grid()
    plt.show()

def plot_loss(history):
    # Plot training and validation loss
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(loc='upper right')
    plt.grid()
    plt.show()

def plot_confusion_matrix(model, x_test, y_test):
    # Predict classes
    y_pred = model.predict(x_test)
    y_pred_classes = np.argmax(y_pred, axis=1)

    # Compute confusion matrix
    cm = confusion_matrix(y_test, y_pred_classes)

    # Display confusion matrix
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=np.unique(y_test), yticklabels=np.unique(y_test))
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# Run experiments with the vanilla ViT and plot the results
vit = create_vit_classifier(vanilla=True)
history_vit = run_experiment(vit)

# Plot accuracy and loss for the vanilla ViT
plot_accuracy(history_vit)
plot_loss(history_vit)
plot_confusion_matrix(vit, test_image, test_labels)

# Run experiments with the Shifted Patch Tokenization and Locality Self Attention modified ViT
vit_sl = create_vit_classifier(vanilla=False)
history_vit_sl = run_experiment(vit_sl)

# Plot accuracy and loss for the modified ViT
plot_accuracy(history_vit_sl)
plot_loss(history_vit_sl)
plot_confusion_matrix(vit_sl, test_image, test_labels)
# Out:
# Epoch 1/50
# 43/43 [==============================] - 31s 379ms/step - loss: 1.9938 - accuracy: 0.5157 - top-5-accuracy: 0.9220 - val_loss: 0.7462 - val_accuracy: 0.7793 - val_top-5-accuracy: 0.9933
# Epoch 2/50
# 43/43 [==============================] - 15s 347ms/step - loss: 0.8662 - accuracy: 0.7013 - top-5-accuracy: 0.9801 - val_loss: 0.5887 - val_accuracy: 0.7751 - val_top-5-accuracy: 0.9925
# Epoch 3/50
# 43/43 [==============================] - 15s 349ms/step - loss: 0.6424 - accuracy: 0.7760 - top-5-accuracy: 0.9909 - val_loss: 0.4309 - val_accuracy: 0.8537 - val_top-5-accuracy: 0.9958
# Epoch 4/50
# 43/43 [==============================] - 15s 354ms/step - loss: 0.5738 - accuracy: 0.8008 - top-5-accuracy: 0.9934 - val_loss: 0.3999 - val_accuracy: 0.8554 - val_top-5-accuracy: 0.9967
# Epoch 5/50
# 43/43 [==============================] - 15s 358ms/step - loss: 0.5193 - accuracy: 0.8144 - top-5-accuracy: 0.9945 - val_loss: 0.4151 - val_accuracy: 0.8562 - val_top-5-accuracy: 0.9950
# Epoch 6/50
# 43/43 [==============================] - 15s 361ms/step - loss: 0.5127 - accuracy: 0.8203 - top-5-accuracy: 0.9948 - val_loss: 0.4466 - val_accuracy: 0.8319 - val_top-5-accuracy: 0.9975
# Epoch 7/50
# 43/43 [==============================] - 16s 369ms/step - loss: 0.4481 - accuracy: 0.8416 - top-5-accuracy: 0.9967 - val_loss: 0.3124 - val_accuracy: 0.8896 - val_top-5-accuracy: 0.9983
# Epoch 8/50
# 43/43 [==============================] - 16s 375ms/step - loss: 0.3880 - accuracy: 0.8664 - top-5-accuracy: 0.9979 - val_loss: 0.3524 - val_accuracy: 0.8737 - val_top-5-accuracy: 0.9958
# Epoch 9/50
# 43/43 [==============================] - 16s 369ms/step - loss: 0.3900 - accuracy: 0.8628 - top-5-accuracy: 0.9976 - val_loss: 0.2574 - val_accuracy: 0.9130 - val_top-5-accuracy: 0.9983
# Epoch 10/50
# 43/43 [==============================] - 16s 364ms/step - loss: 0.3708 - accuracy: 0.8659 - top-5-accuracy: 0.9987 - val_loss: 0.2330 - val_accuracy: 0.9339 - val_top-5-accuracy: 0.9983
# Epoch 11/50
# 43/43 [==============================] - 16s 363ms/step - loss: 0.3017 - accuracy: 0.8954 - top-5-accuracy: 0.9987 - val_loss: 0.2477 - val_accuracy: 0.9247 - val_top-5-accuracy: 0.9992
# Epoch 12/50
# 43/43 [==============================] - 16s 367ms/step - loss: 0.3154 - accuracy: 0.8904 - top-5-accuracy: 0.9989 - val_loss: 0.2629 - val_accuracy: 0.9239 - val_top-5-accuracy: 0.9975
# Epoch 13/50
# 43/43 [==============================] - 16s 370ms/step - loss: 0.3157 - accuracy: 0.8872 - top-5-accuracy: 0.9993 - val_loss: 0.2193 - val_accuracy: 0.9247 - val_top-5-accuracy: 0.9983
# Epoch 14/50
# 43/43 [==============================] - 16s 368ms/step - loss: 0.2905 - accuracy: 0.8984 - top-5-accuracy: 0.9991 - val_loss: 0.2972 - val_accuracy: 0.9038 - val_top-5-accuracy: 1.0000
# Epoch 15/50
# 43/43 [==============================] - 16s 369ms/step - loss: 0.2755 - accuracy: 0.9022 - top-5-accuracy: 0.9995 - val_loss: 0.1911 - val_accuracy: 0.9314 - val_top-5-accuracy: 0.9992
# Epoch 16/50
# 43/43 [==============================] - 16s 368ms/step - loss: 0.2708 - accuracy: 0.9029 - top-5-accuracy: 0.9993 - val_loss: 0.2045 - val_accuracy: 0.9314 - val_top-5-accuracy: 1.0000
# Epoch 17/50
# 43/43 [==============================] - 16s 367ms/step - loss: 0.2598 - accuracy: 0.9086 - top-5-accuracy: 0.9995 - val_loss: 0.2234 - val_accuracy: 0.9189 - val_top-5-accuracy: 0.9983
# Epoch 18/50
# 43/43 [==============================] - 16s 369ms/step - loss: 0.2614 - accuracy: 0.9090 - top-5-accuracy: 0.9993 - val_loss: 0.2078 - val_accuracy: 0.9289 - val_top-5-accuracy: 0.9992
# Epoch 19/50
# 43/43 [==============================] - 16s 369ms/step - loss: 0.2485 - accuracy: 0.9148 - top-5-accuracy: 0.9990 - val_loss: 0.1827 - val_accuracy: 0.9348 - val_top-5-accuracy: 1.0000
# Epoch 20/50
# 43/43 [==============================] - 16s 367ms/step - loss: 0.2292 - accuracy: 0.9189 - top-5-accuracy: 0.9998 - val_loss: 0.1944 - val_accuracy: 0.9465 - val_top-5-accuracy: 1.0000
# Epoch 21/50
# 43/43 [==============================] - 16s 368ms/step - loss: 0.2179 - accuracy: 0.9222 - top-5-accuracy: 0.9996 - val_loss: 0.1902 - val_accuracy: 0.9365 - val_top-5-accuracy: 1.0000
# Epoch 22/50
# 43/43 [==============================] - 16s 370ms/step - loss: 0.2455 - accuracy: 0.9140 - top-5-accuracy: 0.9994 - val_loss: 0.2245 - val_accuracy: 0.9264 - val_top-5-accuracy: 0.9992
# Epoch 23/50
# 43/43 [==============================] - 16s 366ms/step - loss: 0.2518 - accuracy: 0.9119 - top-5-accuracy: 0.9995 - val_loss: 0.1626 - val_accuracy: 0.9423 - val_top-5-accuracy: 0.9992
# Epoch 24/50
# 43/43 [==============================] - 16s 366ms/step - loss: 0.2287 - accuracy: 0.9185 - top-5-accuracy: 0.9995 - val_loss: 0.1525 - val_accuracy: 0.9532 - val_top-5-accuracy: 1.0000
# Epoch 25/50
# 43/43 [==============================] - 16s 369ms/step - loss: 0.2315 - accuracy: 0.9213 - top-5-accuracy: 0.9993 - val_loss: 0.2488 - val_accuracy: 0.9181 - val_top-5-accuracy: 0.9983
# Epoch 26/50
# 43/43 [==============================] - 16s 368ms/step - loss: 0.2490 - accuracy: 0.9139 - top-5-accuracy: 0.9993 - val_loss: 0.1734 - val_accuracy: 0.9415 - val_top-5-accuracy: 0.9992
# Epoch 27/50
# 43/43 [==============================] - 16s 367ms/step - loss: 0.2505 - accuracy: 0.9101 - top-5-accuracy: 0.9996 - val_loss: 0.2006 - val_accuracy: 0.9247 - val_top-5-accuracy: 1.0000
# Epoch 28/50
# 43/43 [==============================] - 16s 367ms/step - loss: 0.2173 - accuracy: 0.9220 - top-5-accuracy: 0.9996 - val_loss: 0.1868 - val_accuracy: 0.9365 - val_top-5-accuracy: 1.0000
# Epoch 29/50
# 43/43 [==============================] - 16s 368ms/step - loss: 0.1921 - accuracy: 0.9335 - top-5-accuracy: 0.9997 - val_loss: 0.1565 - val_accuracy: 0.9523 - val_top-5-accuracy: 1.0000
# Epoch 30/50
# 43/43 [==============================] - 16s 368ms/step - loss: 0.1947 - accuracy: 0.9316 - top-5-accuracy: 0.9998 - val_loss: 0.2194 - val_accuracy: 0.9264 - val_top-5-accuracy: 1.0000
# Epoch 31/50
# 43/43 [==============================] - 16s 368ms/step - loss: 0.2337 - accuracy: 0.9187 - top-5-accuracy: 0.9993 - val_loss: 0.1541 - val_accuracy: 0.9473 - val_top-5-accuracy: 0.9992
# Epoch 32/50
# 43/43 [==============================] - 16s 370ms/step - loss: 0.1845 - accuracy: 0.9365 - top-5-accuracy: 0.9998 - val_loss: 0.1839 - val_accuracy: 0.9431 - val_top-5-accuracy: 1.0000
# Epoch 33/50
# 43/43 [==============================] - 16s 370ms/step - loss: 0.1836 - accuracy: 0.9353 - top-5-accuracy: 0.9998 - val_loss: 0.1825 - val_accuracy: 0.9373 - val_top-5-accuracy: 0.9992
# Epoch 34/50
# 43/43 [==============================] - 16s 370ms/step - loss: 0.1923 - accuracy: 0.9326 - top-5-accuracy: 0.9997 - val_loss: 0.2403 - val_accuracy: 0.9139 - val_top-5-accuracy: 0.9983
# Epoch 35/50
# 43/43 [==============================] - 16s 369ms/step - loss: 0.2172 - accuracy: 0.9240 - top-5-accuracy: 0.9993 - val_loss: 0.1846 - val_accuracy: 0.9373 - val_top-5-accuracy: 0.9983
# Epoch 36/50
# 43/43 [==============================] - 16s 370ms/step - loss: 0.1938 - accuracy: 0.9304 - top-5-accuracy: 0.9998 - val_loss: 0.1840 - val_accuracy: 0.9339 - val_top-5-accuracy: 1.0000
# Epoch 37/50
# 43/43 [==============================] - 16s 369ms/step - loss: 0.1732 - accuracy: 0.9391 - top-5-accuracy: 0.9998 - val_loss: 0.1441 - val_accuracy: 0.9565 - val_top-5-accuracy: 0.9992
# Epoch 38/50
# 43/43 [==============================] - 16s 368ms/step - loss: 0.1917 - accuracy: 0.9341 - top-5-accuracy: 0.9993 - val_loss: 0.1388 - val_accuracy: 0.9532 - val_top-5-accuracy: 1.0000
# Epoch 39/50
# 43/43 [==============================] - 16s 371ms/step - loss: 0.1611 - accuracy: 0.9436 - top-5-accuracy: 1.0000 - val_loss: 0.1532 - val_accuracy: 0.9490 - val_top-5-accuracy: 0.9992
# Epoch 40/50
# 43/43 [==============================] - 16s 369ms/step - loss: 0.1470 - accuracy: 0.9473 - top-5-accuracy: 1.0000 - val_loss: 0.2656 - val_accuracy: 0.9222 - val_top-5-accuracy: 0.9983
# Epoch 41/50
# 43/43 [==============================] - 16s 370ms/step - loss: 0.2496 - accuracy: 0.9165 - top-5-accuracy: 0.9990 - val_loss: 0.1792 - val_accuracy: 0.9415 - val_top-5-accuracy: 0.9992
# Epoch 42/50
# 43/43 [==============================] - 16s 371ms/step - loss: 0.2138 - accuracy: 0.9240 - top-5-accuracy: 0.9997 - val_loss: 0.1786 - val_accuracy: 0.9423 - val_top-5-accuracy: 1.0000
# Epoch 43/50
# 43/43 [==============================] - 16s 370ms/step - loss: 0.1502 - accuracy: 0.9456 - top-5-accuracy: 0.9999 - val_loss: 0.1736 - val_accuracy: 0.9390 - val_top-5-accuracy: 1.0000
# Epoch 44/50
# 43/43 [==============================] - 16s 368ms/step - loss: 0.1699 - accuracy: 0.9400 - top-5-accuracy: 0.9997 - val_loss: 0.1637 - val_accuracy: 0.9515 - val_top-5-accuracy: 0.9992
# Epoch 45/50
# 43/43 [==============================] - 16s 367ms/step - loss: 0.1588 - accuracy: 0.9438 - top-5-accuracy: 0.9999 - val_loss: 0.1508 - val_accuracy: 0.9498 - val_top-5-accuracy: 1.0000
# Epoch 46/50
# 43/43 [==============================] - 16s 369ms/step - loss: 0.1918 - accuracy: 0.9321 - top-5-accuracy: 0.9996 - val_loss: 0.2253 - val_accuracy: 0.9298 - val_top-5-accuracy: 0.9983
# Epoch 47/50
# 43/43 [==============================] - 16s 369ms/step - loss: 0.1759 - accuracy: 0.9404 - top-5-accuracy: 1.0000 - val_loss: 0.1690 - val_accuracy: 0.9507 - val_top-5-accuracy: 1.0000
# Epoch 48/50
# 43/43 [==============================] - 16s 370ms/step - loss: 0.1579 - accuracy: 0.9459 - top-5-accuracy: 1.0000 - val_loss: 0.1377 - val_accuracy: 0.9582 - val_top-5-accuracy: 0.9992
# Epoch 49/50
# 43/43 [==============================] - 16s 370ms/step - loss: 0.1561 - accuracy: 0.9458 - top-5-accuracy: 0.9999 - val_loss: 0.1481 - val_accuracy: 0.9507 - val_top-5-accuracy: 0.9992
# Epoch 50/50
# 43/43 [==============================] - 16s 369ms/step - loss: 0.1471 - accuracy: 0.9495 - top-5-accuracy: 0.9998 - val_loss: 0.1488 - val_accuracy: 0.9515 - val_top-5-accuracy: 0.9992
# 14/14 [==============================] - 2s 118ms/step - loss: 0.1643 - accuracy: 0.9500 - top-5-accuracy: 1.0000
# Test accuracy: 95.0%
# Test top 5 accuracy: 100.0%
# 107/107 [==============================] - 4s 22ms/step
# Epoch 1/50
# 43/43 [==============================] - 31s 446ms/step - loss: 1.9118 - accuracy: 0.5318 - top-5-accuracy: 0.9255 - val_loss: 0.6816 - val_accuracy: 0.7433 - val_top-5-accuracy: 0.9941
# Epoch 2/50
# 43/43 [==============================] - 18s 412ms/step - loss: 0.8639 - accuracy: 0.6916 - top-5-accuracy: 0.9830 - val_loss: 0.6001 - val_accuracy: 0.7943 - val_top-5-accuracy: 0.9900
# Epoch 3/50
# 43/43 [==============================] - 18s 419ms/step - loss: 0.6995 - accuracy: 0.7460 - top-5-accuracy: 0.9888 - val_loss: 0.4952 - val_accuracy: 0.8135 - val_top-5-accuracy: 0.9967
# Epoch 4/50
# 43/43 [==============================] - 17s 396ms/step - loss: 0.6028 - accuracy: 0.7821 - top-5-accuracy: 0.9936 - val_loss: 0.4542 - val_accuracy: 0.8336 - val_top-5-accuracy: 0.9975
# Epoch 5/50
# 43/43 [==============================] - 17s 395ms/step - loss: 0.5300 - accuracy: 0.8145 - top-5-accuracy: 0.9953 - val_loss: 0.4123 - val_accuracy: 0.8487 - val_top-5-accuracy: 0.9983
# Epoch 6/50
# 43/43 [==============================] - 18s 411ms/step - loss: 0.5135 - accuracy: 0.8146 - top-5-accuracy: 0.9950 - val_loss: 0.3644 - val_accuracy: 0.8704 - val_top-5-accuracy: 1.0000
# Epoch 7/50
# 43/43 [==============================] - 17s 401ms/step - loss: 0.4828 - accuracy: 0.8280 - top-5-accuracy: 0.9964 - val_loss: 0.3504 - val_accuracy: 0.8863 - val_top-5-accuracy: 0.9975
# Epoch 8/50
# 43/43 [==============================] - 17s 400ms/step - loss: 0.4513 - accuracy: 0.8388 - top-5-accuracy: 0.9977 - val_loss: 0.3360 - val_accuracy: 0.8813 - val_top-5-accuracy: 0.9992
# Epoch 9/50
# 43/43 [==============================] - 18s 413ms/step - loss: 0.4178 - accuracy: 0.8507 - top-5-accuracy: 0.9966 - val_loss: 0.3120 - val_accuracy: 0.8946 - val_top-5-accuracy: 1.0000
# Epoch 10/50
# 43/43 [==============================] - 17s 399ms/step - loss: 0.4102 - accuracy: 0.8546 - top-5-accuracy: 0.9980 - val_loss: 0.3603 - val_accuracy: 0.8838 - val_top-5-accuracy: 1.0000
# Epoch 11/50
# 43/43 [==============================] - 17s 398ms/step - loss: 0.3816 - accuracy: 0.8571 - top-5-accuracy: 0.9976 - val_loss: 0.3032 - val_accuracy: 0.8930 - val_top-5-accuracy: 1.0000
# Epoch 12/50
# 43/43 [==============================] - 18s 414ms/step - loss: 0.3866 - accuracy: 0.8646 - top-5-accuracy: 0.9980 - val_loss: 0.2940 - val_accuracy: 0.8963 - val_top-5-accuracy: 1.0000
# Epoch 13/50
# 43/43 [==============================] - 17s 399ms/step - loss: 0.3758 - accuracy: 0.8676 - top-5-accuracy: 0.9982 - val_loss: 0.2698 - val_accuracy: 0.8988 - val_top-5-accuracy: 1.0000
# Epoch 14/50
# 43/43 [==============================] - 18s 414ms/step - loss: 0.3669 - accuracy: 0.8689 - top-5-accuracy: 0.9980 - val_loss: 0.2982 - val_accuracy: 0.8955 - val_top-5-accuracy: 0.9983
# Epoch 15/50
# 43/43 [==============================] - 17s 399ms/step - loss: 0.3775 - accuracy: 0.8647 - top-5-accuracy: 0.9979 - val_loss: 0.2866 - val_accuracy: 0.9064 - val_top-5-accuracy: 1.0000
# Epoch 16/50
# 43/43 [==============================] - 18s 413ms/step - loss: 0.3391 - accuracy: 0.8759 - top-5-accuracy: 0.9984 - val_loss: 0.2555 - val_accuracy: 0.9164 - val_top-5-accuracy: 1.0000
# Epoch 17/50
# 43/43 [==============================] - 17s 399ms/step - loss: 0.3263 - accuracy: 0.8828 - top-5-accuracy: 0.9989 - val_loss: 0.2683 - val_accuracy: 0.8988 - val_top-5-accuracy: 1.0000
# Epoch 18/50
# 43/43 [==============================] - 17s 398ms/step - loss: 0.3263 - accuracy: 0.8830 - top-5-accuracy: 0.9985 - val_loss: 0.2546 - val_accuracy: 0.9097 - val_top-5-accuracy: 1.0000
# Epoch 19/50
# 43/43 [==============================] - 17s 400ms/step - loss: 0.2927 - accuracy: 0.8964 - top-5-accuracy: 0.9982 - val_loss: 0.2706 - val_accuracy: 0.8955 - val_top-5-accuracy: 1.0000
# Epoch 20/50
# 43/43 [==============================] - 18s 414ms/step - loss: 0.2934 - accuracy: 0.8973 - top-5-accuracy: 0.9993 - val_loss: 0.2824 - val_accuracy: 0.9055 - val_top-5-accuracy: 0.9992
# Epoch 21/50
# 43/43 [==============================] - 18s 413ms/step - loss: 0.2780 - accuracy: 0.9001 - top-5-accuracy: 0.9992 - val_loss: 0.2725 - val_accuracy: 0.9147 - val_top-5-accuracy: 0.9992
# Epoch 22/50
# 43/43 [==============================] - 17s 399ms/step - loss: 0.2745 - accuracy: 0.9023 - top-5-accuracy: 0.9995 - val_loss: 0.2675 - val_accuracy: 0.9072 - val_top-5-accuracy: 0.9983
# Epoch 23/50
# 43/43 [==============================] - 18s 413ms/step - loss: 0.2793 - accuracy: 0.8993 - top-5-accuracy: 0.9992 - val_loss: 0.2819 - val_accuracy: 0.8988 - val_top-5-accuracy: 1.0000
# Epoch 24/50
# 43/43 [==============================] - 18s 415ms/step - loss: 0.2695 - accuracy: 0.9016 - top-5-accuracy: 0.9993 - val_loss: 0.2506 - val_accuracy: 0.9130 - val_top-5-accuracy: 1.0000
# Epoch 25/50
# 43/43 [==============================] - 18s 414ms/step - loss: 0.2647 - accuracy: 0.9024 - top-5-accuracy: 0.9997 - val_loss: 0.2671 - val_accuracy: 0.9038 - val_top-5-accuracy: 0.9967
# Epoch 26/50
# 43/43 [==============================] - 18s 415ms/step - loss: 0.2801 - accuracy: 0.8990 - top-5-accuracy: 0.9985 - val_loss: 0.3431 - val_accuracy: 0.8771 - val_top-5-accuracy: 1.0000
# Epoch 27/50
# 43/43 [==============================] - 18s 414ms/step - loss: 0.2822 - accuracy: 0.8993 - top-5-accuracy: 0.9993 - val_loss: 0.3328 - val_accuracy: 0.8829 - val_top-5-accuracy: 0.9975
# Epoch 28/50
# 43/43 [==============================] - 18s 414ms/step - loss: 0.2557 - accuracy: 0.9071 - top-5-accuracy: 0.9990 - val_loss: 0.2236 - val_accuracy: 0.9247 - val_top-5-accuracy: 0.9992
# Epoch 29/50
# 43/43 [==============================] - 18s 414ms/step - loss: 0.2290 - accuracy: 0.9164 - top-5-accuracy: 0.9997 - val_loss: 0.2942 - val_accuracy: 0.8997 - val_top-5-accuracy: 1.0000
# Epoch 30/50
# 43/43 [==============================] - 18s 414ms/step - loss: 0.3086 - accuracy: 0.8916 - top-5-accuracy: 0.9986 - val_loss: 0.2835 - val_accuracy: 0.8997 - val_top-5-accuracy: 0.9992
# Epoch 31/50
# 43/43 [==============================] - 18s 413ms/step - loss: 0.2882 - accuracy: 0.8947 - top-5-accuracy: 0.9993 - val_loss: 0.2489 - val_accuracy: 0.9156 - val_top-5-accuracy: 0.9992
# Epoch 32/50
# 43/43 [==============================] - 18s 413ms/step - loss: 0.2713 - accuracy: 0.9010 - top-5-accuracy: 0.9989 - val_loss: 0.2191 - val_accuracy: 0.9256 - val_top-5-accuracy: 1.0000
# Epoch 33/50
# 43/43 [==============================] - 17s 400ms/step - loss: 0.2296 - accuracy: 0.9156 - top-5-accuracy: 0.9996 - val_loss: 0.2902 - val_accuracy: 0.8988 - val_top-5-accuracy: 0.9992
# Epoch 34/50
# 43/43 [==============================] - 18s 413ms/step - loss: 0.2860 - accuracy: 0.8944 - top-5-accuracy: 0.9993 - val_loss: 0.2359 - val_accuracy: 0.9206 - val_top-5-accuracy: 0.9992
# Epoch 35/50
# 43/43 [==============================] - 18s 414ms/step - loss: 0.2503 - accuracy: 0.9123 - top-5-accuracy: 0.9994 - val_loss: 0.2128 - val_accuracy: 0.9222 - val_top-5-accuracy: 0.9992
# Epoch 36/50
# 43/43 [==============================] - 18s 414ms/step - loss: 0.2159 - accuracy: 0.9196 - top-5-accuracy: 0.9996 - val_loss: 0.2369 - val_accuracy: 0.9214 - val_top-5-accuracy: 1.0000
# Epoch 37/50
# 43/43 [==============================] - 18s 414ms/step - loss: 0.2043 - accuracy: 0.9249 - top-5-accuracy: 0.9996 - val_loss: 0.2200 - val_accuracy: 0.9156 - val_top-5-accuracy: 1.0000
# Epoch 38/50
# 43/43 [==============================] - 18s 414ms/step - loss: 0.2119 - accuracy: 0.9231 - top-5-accuracy: 0.9994 - val_loss: 0.2642 - val_accuracy: 0.9139 - val_top-5-accuracy: 1.0000
# Epoch 39/50
# 43/43 [==============================] - 18s 413ms/step - loss: 0.2669 - accuracy: 0.9059 - top-5-accuracy: 0.9988 - val_loss: 0.2163 - val_accuracy: 0.9247 - val_top-5-accuracy: 1.0000
# Epoch 40/50
# 43/43 [==============================] - 18s 414ms/step - loss: 0.2145 - accuracy: 0.9221 - top-5-accuracy: 0.9995 - val_loss: 0.1925 - val_accuracy: 0.9356 - val_top-5-accuracy: 0.9992
# Epoch 41/50
# 43/43 [==============================] - 18s 413ms/step - loss: 0.1849 - accuracy: 0.9308 - top-5-accuracy: 0.9997 - val_loss: 0.1954 - val_accuracy: 0.9373 - val_top-5-accuracy: 1.0000
# Epoch 42/50
# 43/43 [==============================] - 17s 400ms/step - loss: 0.1863 - accuracy: 0.9340 - top-5-accuracy: 0.9999 - val_loss: 0.2373 - val_accuracy: 0.9214 - val_top-5-accuracy: 1.0000
# Epoch 43/50
# 43/43 [==============================] - 17s 399ms/step - loss: 0.1861 - accuracy: 0.9356 - top-5-accuracy: 0.9998 - val_loss: 0.1968 - val_accuracy: 0.9298 - val_top-5-accuracy: 1.0000
# Epoch 44/50
# 43/43 [==============================] - 17s 400ms/step - loss: 0.1922 - accuracy: 0.9317 - top-5-accuracy: 0.9999 - val_loss: 0.2066 - val_accuracy: 0.9314 - val_top-5-accuracy: 1.0000
# Epoch 45/50
# 43/43 [==============================] - 17s 400ms/step - loss: 0.1912 - accuracy: 0.9308 - top-5-accuracy: 0.9996 - val_loss: 0.2422 - val_accuracy: 0.9314 - val_top-5-accuracy: 1.0000
# Epoch 46/50
# 43/43 [==============================] - 18s 414ms/step - loss: 0.1738 - accuracy: 0.9399 - top-5-accuracy: 0.9999 - val_loss: 0.1965 - val_accuracy: 0.9390 - val_top-5-accuracy: 1.0000
# Epoch 47/50
# 43/43 [==============================] - 18s 415ms/step - loss: 0.1868 - accuracy: 0.9325 - top-5-accuracy: 0.9994 - val_loss: 0.1971 - val_accuracy: 0.9390 - val_top-5-accuracy: 1.0000
# Epoch 48/50
# 43/43 [==============================] - 17s 399ms/step - loss: 0.1832 - accuracy: 0.9351 - top-5-accuracy: 0.9996 - val_loss: 0.2083 - val_accuracy: 0.9348 - val_top-5-accuracy: 0.9992
# Epoch 49/50
# 43/43 [==============================] - 17s 401ms/step - loss: 0.1908 - accuracy: 0.9305 - top-5-accuracy: 0.9999 - val_loss: 0.1898 - val_accuracy: 0.9381 - val_top-5-accuracy: 0.9992
# Epoch 50/50
# 43/43 [==============================] - 18s 414ms/step - loss: 0.1785 - accuracy: 0.9371 - top-5-accuracy: 0.9997 - val_loss: 0.2291 - val_accuracy: 0.9331 - val_top-5-accuracy: 0.9992
# 14/14 [==============================] - 2s 136ms/step - loss: 0.2525 - accuracy: 0.9182 - top-5-accuracy: 0.9988
# Test accuracy: 91.82%
# Test top 5 accuracy: 99.88%
# 107/107 [==============================] - 4s 25ms/step
